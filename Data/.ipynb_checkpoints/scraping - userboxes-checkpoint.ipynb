# %%
user = "The Devil's Advocate"
url = "https://en.wikipedia.org/w/index.php?title=User:" + user + "&action=edit"

# %%
import requests

headers = {
    'From': '<jf3105@columbia.edu>'
    #'User-Agent': '...'
}
response = requests.get(url, headers=headers)

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(response.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    View source for User:The Devil's Advocate - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
#   </script>
#   <script>
#    (window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"User","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":2,"wgPageName":"User:The_Devil's_Advocate","wgTitle":"The Devil's Advocate","wgCurRevisionId":795775466,"wgRevisionId":0,"wgArticleId":14531828,"wgIsArticle":false,"wgIsRedirect":false,"wgAction":"edit","wgUserName":null,"wgUserGroups":["*"],"wgCategories":[],"wgBreakFrames":true,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"User:The_Devil's_Advocate","wgRelevantArticleId":14531828,"wgRequestId":"WucgqApAME0AAKxLUZEAAABK","wgIsProbablyEditable":false,"wgRelevantPageIsProbablyEditable":false,"wgRestrictionEdit":["sysop"],"wgRestrictionMove":[],"wgRelevantUserName":"The Devil's Advocate","wgFlaggedRevsParams":{"tags":{}},"wgStableRevisionId":null,"wgCategoryTreePageCategoryOptions":"{\"mode\":0,\"hideprefix\":20,\"showcount\":true,\"namespaces\":false}","wgWikiEditorEnabledModules":[],"wgBetaFeaturesFeatures":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsShouldSendModuleToUser":true,"wgPopupsConflictsWithNavPopupGadget":false,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en","usePageImages":true,"usePageDescriptions":true},"wgPreferredVariant":"en","wgMFExpandAllSectionsUserOption":true,"wgMFEnableFontChanger":true,"wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":false},"wgRelatedArticles":null,"wgRelatedArticlesUseCirrusSearch":true,"wgRelatedArticlesOnlyUseCirrusSearch":false,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralNoticeCookiesToDelete":[],"wgCentralNoticeCategoriesUsingLegacy":["Fundraising","fundraising"],"wgScoreNoteLanguages":{"arabic":"العربية","catalan":"català","deutsch":"Deutsch","english":"English","espanol":"español","italiano":"italiano","nederlands":"Nederlands","norsk":"norsk","portugues":"português","suomi":"suomi","svenska":"svenska","vlaams":"West-Vlams"},"wgScoreDefaultNoteLanguage":"nederlands","wgCentralAuthMobileDomain":false,"wgCodeMirrorEnabled":false,"wgVisualEditorToolbarScrollOffset":0,"wgVisualEditorUnsupportedEditParams":["undo","undoafter","veswitched"],"wgEditSubmitButtonLabelPublish":true});mw.loader.state({"ext.gadget.charinsert-styles":"ready","ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","user":"ready","user.options":"ready","user.tokens":"loading","ext.charinsert.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","mediawiki.sectionAnchor":"ready","mediawiki.ui.button":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready"});mw.loader.implement("user.tokens@1dqfd7l",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"editToken":"+\\","patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# });mw.loader.load(["mediawiki.action.edit.collapsibleFooter","site","mediawiki.page.startup","mediawiki.user","mediawiki.hidpi","mediawiki.page.ready","mediawiki.searchSuggest","ext.charinsert","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging.subscriber","ext.wikimediaEvents","ext.navigationTiming","ext.uls.eventlogger","ext.uls.init","ext.uls.compactlinks","ext.uls.interface","ext.3d","ext.centralNotice.geoIP","skins.vector.js"]);});
#   </script>
#   <link href="/w/load.php?debug=false&amp;lang=en&amp;modules=ext.charinsert.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.sectionAnchor%7Cmediawiki.skinning.interface%7Cmediawiki.ui.button%7Cskins.vector.styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <script async="" src="/w/load.php?debug=false&amp;lang=en&amp;modules=startup&amp;only=scripts&amp;skin=vector">
#   </script>
#   <meta content="" name="ResourceLoaderDynamicStyles"/>
#   <link href="/w/load.php?debug=false&amp;lang=en&amp;modules=ext.gadget.charinsert-styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <link href="/w/load.php?debug=false&amp;lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <meta content="MediaWiki 1.32.0-wmf.1" name="generator"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="origin-when-crossorigin" name="referrer"/>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <meta content="noindex,nofollow" name="robots"/>
#   <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
#   <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
#   <link href="/w/opensearch_desc.php" rel="search" title="Wikipedia (en)" type="application/opensearchdescription+xml"/>
#   <link href="//en.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
#   <link href="//creativecommons.org/licenses/by-sa/3.0/" rel="license"/>
#   <link href="/w/index.php?title=Special:RecentChanges&amp;feed=atom" rel="alternate" title="Wikipedia Atom feed" type="application/atom+xml"/>
#   <link href="https://en.wikipedia.org/wiki/User:The_Devil%27s_Advocate" rel="canonical"/>
#   <link href="//login.wikimedia.org" rel="dns-prefetch"/>
#   <!--[if lt IE 9]><script src="/w/load.php?debug=false&amp;lang=en&amp;modules=html5shiv&amp;only=scripts&amp;skin=vector&amp;sync=1"></script><![endif]-->
#  </head>
#  <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-2 ns-subject page-User_The_Devil_s_Advocate rootpage-User_The_Devil_s_Advocate skin-vector action-edit">
#   <div class="noprint" id="mw-page-base">
#   </div>
#   <div class="noprint" id="mw-head-base">
#   </div>
#   <div class="mw-body" id="content" role="main">
#    <a id="top">
#    </a>
#    <div class="mw-body-content" id="siteNotice">
#     <!-- CentralNotice -->
#    </div>
#    <div class="mw-indicators mw-body-content">
#    </div>
#    <h1 class="firstHeading" id="firstHeading" lang="en">
#     View source for User:The Devil's Advocate
#    </h1>
#    <div class="mw-body-content" id="bodyContent">
#     <div id="contentSub">
#      ←
#      <a href="/wiki/User:The_Devil%27s_Advocate" title="User:The Devil's Advocate">
#       User:The Devil's Advocate
#      </a>
#     </div>
#     <div class="mw-jump" id="jump-to-nav">
#      Jump to:
#      <a href="#mw-head">
#       navigation
#      </a>
#      ,
#      <a href="#p-search">
#       search
#      </a>
#     </div>
#     <div id="mw-content-text">
#      <p>
#       You do not have permission to edit this page, for the following reason:
#      </p>
#      <div class="permissions-errors">
#       <table class="plainlinks fmbox fmbox-system" id="mw-protectedpagetext" role="presentation" style="border-style:none;">
#        <tr>
#         <td class="mbox-text">
#          <table class="plainlinks ombox ombox-protection" role="presentation">
#           <tr>
#            <td class="mbox-image">
#             <img alt="" data-file-height="128" data-file-width="128" height="40" src="//upload.wikimedia.org/wikipedia/en/thumb/5/59/Padlock.svg/40px-Padlock.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/5/59/Padlock.svg/60px-Padlock.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/5/59/Padlock.svg/80px-Padlock.svg.png 2x" width="40"/>
#            </td>
#            <td class="mbox-text" style="font-weight:bold; font-size:130%;">
#             This page is currently
#             <a href="/wiki/Wikipedia:Protection_policy#Full_protection" title="Wikipedia:Protection policy">
#              protected
#             </a>
#             so that only
#             <a href="/wiki/Wikipedia:Administrators" title="Wikipedia:Administrators">
#              administrators
#             </a>
#             can edit it.
#            </td>
#           </tr>
#          </table>
#          <table style="margin-top:1em; background:none;">
#           <tr>
#            <td style="width:50%; vertical-align:top;">
#             <div style="width:80%; vertical-align:top; background:transparent;">
#              <div style="position:relative; height:25px; left:1.3em; top:4px;">
#               <h2 style="border-bottom:0; font-size:130%; font-weight:bold; padding:.15em;">
#                <span id="Why_is_the_page_protected.3F">
#                </span>
#                <span class="mw-headline" id="Why_is_the_page_protected?">
#                 Why is the page protected?
#                </span>
#               </h2>
#              </div>
#              <ul>
#               <li>
#                Some
#                <a href="/wiki/Wikipedia:Template_messages" title="Wikipedia:Template messages">
#                 templates
#                </a>
#                and site interface pages are permanently
#                <a href="/wiki/Wikipedia:Protection_policy#Full_protection" title="Wikipedia:Protection policy">
#                 protected
#                </a>
#                due to visibility. Occasionally, articles are temporarily protected because of
#                <a class="mw-redirect" href="/wiki/Wikipedia:Edit_war" title="Wikipedia:Edit war">
#                 editing disputes
#                </a>
#                . Most articles can be edited by anyone.
#               </li>
#               <li>
#                The reason for protection can be found in the
#                <a class="external text" href="//en.wikipedia.org/w/index.php?title=Special:Log&amp;type=protect&amp;page=User%3AThe+Devil%26%2339%3Bs+Advocate">
#                 protection log
#                </a>
#                . If there are no relevant entries in the protection log, the page may have been moved after being protected.
#               </li>
#              </ul>
#             </div>
#            </td>
#            <td style="width:50%; vertical-align:top;">
#             <div style="position:relative; height:25px; left:1.3em; top:4px;">
#              <h2 style="border-bottom:0; font-size:130%; font-weight:bold; padding:.15em;">
#               <span id="What_can_I_do.3F">
#               </span>
#               <span class="mw-headline" id="What_can_I_do?">
#                What can I do?
#               </span>
#              </h2>
#             </div>
#             <ul>
#              <li>
#               <a href="/wiki/User_talk:The_Devil%27s_Advocate" title="User talk:The Devil's Advocate">
#                Discuss this page
#               </a>
#               with others.
#              </li>
#              <li>
#               For move-protected pages, see
#               <a href="/wiki/Wikipedia:Requested_moves" title="Wikipedia:Requested moves">
#                requested moves
#               </a>
#               .
#              </li>
#              <li>
#               <a href="/wiki/Wikipedia:Requests_for_page_protection#Current_requests_for_reduction_in_protection_level" title="Wikipedia:Requests for page protection">
#                Request that the page's protection level be reduced
#               </a>
#               .
#              </li>
#              <li>
#               <a class="mw-redirect" href="/wiki/Wikipedia:New_contributors%27_help_page" title="Wikipedia:New contributors' help page">
#                Find out more about how to get started editing Wikipedia
#               </a>
#               .
#              </li>
#              <li>
#               If you have noticed an error or have a suggestion for a simple, non-controversial  change, you can submit an edit request, by clicking the button below and following instructions. An
#               <a href="/wiki/Wikipedia:Administrators" title="Wikipedia:Administrators">
#                administrator
#               </a>
#               may then make the change on your behalf. Please check
#               <a href="/wiki/User_talk:The_Devil%27s_Advocate" title="User talk:The Devil's Advocate">
#                the talk page
#               </a>
#               first in case the issue is already being discussed.
#              </li>
#              <li style="list-style:none; display:inline;">
#               <div style="text-align:center; margin:auto;">
#                <p>
#                 <span class="plainlinks">
#                  <a class="external text" href="//en.wikipedia.org/wiki/Wikipedia:Requests_for_page_protection#Current_requests_for_edits_to_a_protected_page">
#                   <span class="mw-ui-button mw-ui-progressive">
#                    Submit an edit request
#                   </span>
#                  </a>
#                 </span>
#                </p>
#               </div>
#              </li>
#             </ul>
#            </td>
#           </tr>
#          </table>
#         </td>
#        </tr>
#       </table>
#      </div>
#      <hr/>
#      <div id="viewsourcetext">
#       You can view and copy the source of this page:
#      </div>
#      <textarea accesskey="," class="mw-editfont-monospace" cols="80" dir="ltr" id="wpTextbox1" lang="en" name="wpTextbox1" readonly="" rows="25" style="">{{pp-protected|reason=gravedancing and edit warring over a freakin' user page|small=yes}}
#
# {{banned|by=the [[WP:AC|Arbitration Committee]]|link=[[Special:Permalink/697679352#The Devil's Advocate banned|announcement]]}}
# {{banned user}}
# {{reviewer topicon|icon_nr=1}}
# {{Rollback topicon|icon_nr=2}}
# {{user new message}}
#
# {{Userboxtop|The Devil's Advocate|bordercolor=#000000}}
# {{User:Jer10 95/privatename}}
# {{user:hmwith/ubx/male}}
# {{User:UserBox/User Earthling}}
# {{user en}}
# {{User:Ashley Y/Userbox/Agnostic}}
# {{User:UBX/girlfriendwish}}
# {{User:JLogan/LesSym}}
# {{User:UBX/Coke Pepsi}}
# {{Template:user ancestry multi}}
# {{Template:User Immortal}}
# {{User Wikimedia Commons}}
# {{userbox
# |id=[[File:Box-cutter.jpg|50px]]
# |info=This user reads '''[[Wikipediocracy]]'''
# }}
# {{User:Boing! said Zebedee/Userboxes/noadmin}}
# {{User:UBX/Twinkle4}}
# {{User wikipedia/WikiDragon2}}
# {{User edit}}
# {{User recursively neutral}}
# {{User:SpeakFree/no barnstar}}
# {{Template:User WikiPeace}}
# {{User:Running/wikipe-tan}}
# {{User:JohnRussell/wikipedianumedits|19,000}}
# {{User:Timeastor/personality versatile}}
# {{User:Menasim/Userboxes/User quote|"All men can be criminals, if tempted; all men can be heroes, if inspired."
# |G. K. Chesterton}}
# {{User:Scepia/beauty}}
# {{User:Scepia/HDTV}}
# {{User:Feureau/UserBox/ubx-5}}
# {{Userboxbottom}}
# &lt;div&gt;
# &lt;center&gt;
# &lt;div style=" padding:0px; margin:0px;background:#ffffff; border-top:1px solid #ff9933; border-left:1px solid #ff9933; border-right:1px solid #ff9933;"&gt;
# &lt;center&gt;[[Special:Contributions/The Devil's Advocate|Contributions]] | [[User:The Devil's Advocate/Sandbox|Sand Box]] | [[User:The Devil's Advocate/drafts|Drafts]] | [[User:The Devil's Advocate/Links|Links]]| [[User:The Devil's Advocate/GeneralMusings|General Musings]]&lt;/center&gt;&lt;/div&gt;
# &lt;div style=" padding:0px; margin-bottom:5px;background:#eee; border-bottom:1px solid #ccc;border-left:1px solid #ccc; border-right:1px solid #ccc;"&gt;
# &lt;/div&gt;
# &lt;/center&gt;
# &lt;/div&gt;
#
# [[File:Uncle Wikipe-tan.png|600px]]
#
# ==About me==
# My first foray into editing Wikipedia was updating the article on the [[Six-party talks]] over North Korea's nuclear weapons program. Gradually, I moved into editing about regional unions and other political topics, such as the 2008 U.S. Presidential primaries and articles about geopolitical developments. This included my first trial by fire when a geopolitics article I created wound up at Articles for Deletion due to a rather poor naming choice on my part. On several occasions during my time editing here I have become so disenchanted with the flaws in the process that it prompted lulls in my editing with the most recent one having been for a couple of months and the longest one being for about a year. In the past two years I have diversified my content contributions to focus less on politics, which has often proven too stressful for an enjoyable editing experience.
#
# Although I started out being mostly interested in contributing content, the various situations I have confronted on Wikipedia have prompted me to show a more general concern over this site's culture and governance. I have been involved in the Wikipedia criticism site [[Wikipediocracy]] for over two years because of this, although anyone there can tell you of the many times when I am not on their side either. My concerns about Wikipedia also mean I was more of a regular on various conduct noticeboards and sometimes weighed in on [[Wikipedia:Arbitration|arbitration]] matters until I took [[Wikipedia:Arbitration/Requests/Case/GamerGate|an arbitration case]] to the knee. Typically, I only become involved when I notice a particular problem is not being discussed or feel one or more editors are being treated unfairly.
#
# In addition to my contributions on the Wikimedia projects, I have become fairly active on the [http://rwby.wikia.com/wiki/User:The_Devil%27s_Advocate_WP RWBY Wiki] hosted by Wikia. Outside my involvement with wikis, my time on the Internet is mostly spent doing typical Internet things of no consequence. During my time off-line I similarly do things of little consequence and am generally a person of no consequence to anyone, even in my humble rural community, though as [[Revolution (Beatles song)|the song]] goes "we all want to change the world" and I do hope I could have a realistic chance at that one day.
# == My editing philosophy ==
#
# In my editing I strive to take the approach of a [[Bohemianism|Bohemian]] Wikipedian. I draw my inspiration from the values espoused in the film [[Moulin Rouge!]] of [[Truth]], [[Beauty]], [[Liberty|Freedom]], and [[Love]]. These also reflect the kind of values I try to uphold in life. As it pertains to Wikipedia I apply these values in this way:
#
# *'''Truth''' - Far too often people take the dictum of [[WP:V|verifiability, not truth]] too far by presuming that if a reliable source can be found to make the claim then it is ok for Wikipedia to say it in the editorial voice. Usually this occurs because of an editor's own bias seeping into his or her editing process. At times because there is an absence of contravening sources editors similarly feel confident in using stronger language than that of their sources. However, I believe this goes against an unspoken rule that Wikipedia should always strive for factual accuracy. I seek to counter the [[systemic bias]] that often works its way into contentious topic areas in pursuit of the greater truth. That means using the most [[WP:NPOV|neutral]] wording the sources support and, save for "[[WP:BLUE|sky is blue]]"-type situations, [[WP:INTEXT|in-text attribution]] should be the norm. The goal is making the project a place to find the whole story with eyes unclouded by prejudice, contrary to the more controlled sources of information in the world.
# *'''Beauty''' - When it comes to any article one is likely to find more than a few instances of repetition and less-than-engaging wording. One of my objectives in contributing to Wikipedia is to improve the stylistic appearance of any article I come across. That means, to provide an example, trimming down the instances of paragraphs starting with the same letter, and especially the same word. Another big issue is avoiding the timeline-like style certain articles about ongoing events tend to take on out of a general apathy of editors. By beautifying the project wherever I can my hope is that more readers will be engaged with the repository of knowledge Wikipedia represents.
# *'''Freedom''' - This project is first and foremost an experiment in information democracy. Submitting the whole of human ingenuity and knowledge to the task of building a source of knowledge for all requires great care and consideration. As predicted by the [[iron law of oligarchy]], Wikipedia has fallen prey to the same abusive tendencies of any governance system. Rule by [[consensus]] may appear to be a policy to cherish, but it is all too often misused by editors to impose their own will on the project. [[WP:AGF|Assuming good faith]] keeps us willfully blind to some extent about what is taking place. Look through any article in a contentious topic area and you are liable to find a consortium of editors from the same ideological persuasion who have become the page's self-appointed gatekeepers. Enterprising users who go against their will often find themselves driven away, whether it is by falling into a [[WP:edit war|revert trap]] or simply becoming frustrated with endless [[WP:STONEWALL|stone-walling]]. Unfortunately, Wikipedia looks more favorably upon the gatekeepers as they greatly outnumber their opponent. Always looking for a way to satisfy all parties without compromising my principles and drawing attention to the biases of all sides is the best way I can think of to insure this experiment remains open to as many people as possible.
# *'''Love''' - Above all things I believe in [[WP:WikiLove|WikiLove]]. [[Love is Like Oxygen|WikiLove is like oxygen]]. [[Up Where We Belong|WikiLove lifts us up where we belong]]. [[All You Need Is Love|All you need is WikiLove]]. For me it means keeping an open mind on all things. Were more editors to leave themselves open it would be easier to defuse most disputes. Remain open to having your edits rewritten. Remain open to changing your mind. Remain open to changing your actions even if you won't change your mind. Too much potential is lost in the ideological rigidity of [[groupthink]] and [[confirmation bias]]. Pursuit of WikiLove means that the only things we should try to take seriously are the feelings of others. Sometimes it is hard to [[WP:COOL|stay cool]] and we have all been there at one point or another. We should thus [[User:Heimstern/Ignoring incivility|not let an occasional lapse]] determine someone's fate as none of us are perfect. Keep in mind that we do this not for ourselves, but for all those who may witness this body of work.
#
# To sum it all up, my goal is to try and uphold the idea of what Wikipedia can be, while dealing with the reality of what Wikipedia is at this moment. More than anything I want this project to be a great service to all truth-seekers in the world. It should be a light of knowledge in dark places when all other lights go out. One could say that I am a true believer when it comes to this idea and, even if it leaves me battered and bruised, I will strive to defend the principles of this project above all else.
#
# == Things to do ==
# {{See also|User:The Devil's Advocate/List of priority articles|label 1=List of priority articles}}
# {{col-begin}}
# | width="50%" align="{{{align|left}}}" valign="{{{valign|top}}}" style="border:0"|
# *Create article on [[E*Trade]] baby.
# *Turn [[Wikipedia:Inaccuracy]] into a fitting proposal for a guideline.
# *Write essay on "camping" at articles.
# *Write essay on "railroading" by groups to potentially link with camping.
# *Write essay on "echo chamber" to discuss [[groupthink]] on Wikipedia to link from camping and railroading.
# *Write essay on "doubling down" in contentious disputes.
# *Create article on Consolidated Restaurant Operations for possible merge with [[Dixie House]] article.
# *Create article on WiseGeek.
# *Expand article on [[Google Panda]] and [[content farm]].
# *Create article on Caroline Rose Hunt.
# *Create article on Maritz, Wolff &amp; Co.
# *Create article on Sheppard King.
# *Create article on Americas Lodging Investment Summit.
# *Expand [[AAA Five Diamond Award]] article.
# *Rewrite [[Perkins Coie]] article.
# *Rewrite articles on Rosewood properties.
# *Expand [[New World China Land]] article.
# *Rewrite articles on [[Resort]] and [[Hotel]].
# *Expand [[Sowwah]] article.
# *Create article on Sonia Cheng.
# *Write Essay on under-served topic areas.
# *Create article on US Azeris Network.
# *Write Essay on wikipartisans.
# *Expand article on [[Stefaan Engels]].
# *Create article on Chuck Engle.
# *Create article on Running Times Magazine.
# *Improve article on [[Runner's World]] Magazine.
# *Create article on Melissa Gillette.
# *Create article on Doug Kurtis.
# *Expand article on [[Association of Road Racing Statisticians]].
# *Create article on indoor marathons.
# *Turn [[Wikipedia:Notability (fiction)]] into a fitting proposal for a guideline.
# *Create article on Tim Siedell.
# | width="50%" align="{{{align|left}}}" valign="{{{valign|top}}}" style="border:0"|
# *Create article on Canadian Running magazine.
# *Create article on Sunbelt Ag Expo.
# *Create article on James Chen President of [[Chinatrust Commercial Bank]].
# *Create article on James Chen Founder of Adlens.
# *Create article on Adlens.
# *Create article on Alliance Magazine.
# *Create article on Kim Klein.
# *Create article on political support of Ron Paul.
# *Create article on media coverage of Ron Paul.
# *Create article on John Ramsey.
# *Create article on Marshall Home.
# *Create article on Wikimedia Germany.
# *Create article on Wikimedia France.
# *Create article on Christopher Dennis.
# *Create article on Jon Davies.
# *Create article on Raymond Cox (Stallion83)
# *Create article on Cole Stryker.
# *Create article on Doritos Locos Tacos.
# *Create article on Moanin' (song).
# *Create article on We Are Change.
# *Create article on Luke Rudkowski.
# *Create article on ''Intelligence and How to Get It''.
# *Create article on ''Genes, People, and Languages''.
# *Create article on The Amazing Atheist.
# *Create article on Reginald T. Dorsey.
# *Create article on Ice Princess saga.
# *Recreate article on Flightless Bird, American Mouth
# *Create article on ''Interventions: A Life in War and Peace''
# *Create article on Nader Mousavizadeh
# *Create article on Carrie the dancing dog
# *Create article on ''Hot Chocolate Nutcracker''
# *Create article on Virginia "Ginny" Busch
# *Create article on Poornima Vijayashanker
# *Create article on Tracy Chou
# {{col-end}}
#
# == Articles I've created ==
#
# * [[Grassroots fundraising]]
# * [[Kosovo independence precedent]]
# * [[2008 Andean diplomatic crisis]]
# * [[2008 unrest in Kosovo]]
# * [[International Steering Group for Kosovo]]
# * [[Kosovan local elections, 2008]]
# * [[David E. Carter]]
# * [[European Grouping for Territorial Cooperation]]
# * [[2008 Georgia-Russia crisis‎]]
# * [[2008 Djiboutian-Eritrean border conflict]]
# * [[2008 Ukrainian political crisis]]
# * [[2008 unrest in Bolivia]]
# * [[Bankruptcy of Lehman Brothers]]
# * [[Sosie Bacon]]
# * [[North American integration]]
# * [[Xue Hanqin]]
# * [[Krista Branch]] {{icon|GA}}
# * [[MovieWeb]] {{icon|DYK}}
# * [[Wikimedia UK]] {{icon|DYK}}
# * [[List of The Host characters|List of ''The Host'' characters]]
# * [[List of Revolution episodes|List of ''Revolution'' episodes]]
# * [[General Hospital's 50th anniversary]] {{icon|DYK}}
# * [[The Fine Young Capitalists]] {{icon|DYK}}
#
# == Articles where I've made major contributions ==
#
# * [[Moneybomb]]
# * [[North American Union]]
# * [[Conspiracy theory]]
# * [[NAFTA Superhighway]]
# * [[Late-2000s recession]]
# * [[Battle of the Kodori Valley]]
# * [[Twelve Oaks Mall]]
# * [[Abdul Rahman Hassan Azzam]]
# * [[Collapse of the World Trade Center]]
# * [[7 World Trade Center]]
# * [[1948 Arab–Israeli War]]
# * [[Zhijian James Chen]]
# * [[Giordano's Pizzeria]]
# * [[Emily Thorne]]
# * [[Charlie Engle (infielder)]] {{icon|DYK}}
# * [[Bai Yansong]] {{icon|DYK}}
# * [[Anna Azari]] {{icon|DYK}}
# * [[List of Wikipedia controversies]] [[File:Dollar symbol gold.svg|10px|Cha-ching!]]
# * [[Wikipediocracy]]
# * ''[[RWBY]]'' {{icon|DYK}}
# * [[List of RWBY episodes|List of ''RWBY'' episodes]]
# * [[Pricasso]]
# * [[Stanton Foundation]] [[File:Dollar symbol gold.svg|10px|Cha-ching!]]
#
# == Essays I've written ==
# * [[Wikipedia:Disruptive sanctions]]
#
# == Good article nominations I've reviewed ==
# *[[Talk:Otis Redding/GA3|Otis Redding]] (second opinion)
# *[[Talk:Revelation (Third Day album)/GA1|Revelation (Third Day album)]]
# *[[Talk:History of Evansville, Indiana/GA1|History of Evansville, Indiana]]
# *[[Talk:Anne Rice/GA1|Anne Rice]]
# *[[Talk:Brooks &amp; Dunn/GA1|Brooks &amp; Dunn]]
# *[[Talk:James Randi/GA1|James Randi]]
# *[[Talk:Knights of Columbus/GA1|Knights of Columbus]]
# *[[Talk:Paul Ryan/GA1|Paul Ryan]]
#
# == Tools ==
# *[https://tools.wmflabs.org/xtools/topedits/index.php? Top namespace edits]
# *[http://toolserver.org/~mzmcbride/stalker/ Wikistalk]
# *[http://toolserver.org/~snottywong/editorinteract.html Editor interaction analyzer]
# *[http://toolserver.org/~tparis/autoedits/ Automated edit counter]
# *[http://toolserver.org/~snottywong/adminscore.html Admin score]
#
# == Userboxes ==
# {{collapse top|Politics}}
# {| class="wikitable"
# |-
# | {{Template:user history2}}
# | {{User:Scepia/geopolitics}}
# | {{User:J.P.Lon/Userboxes/Interest-Economics}}
# |-
# | {{User:Quoth the Raven/Userboxes/Political Science}}
# | {{User:Gordalmighty/Userbox/Ron Paul}}
# |  {{User:Dailynetworks/ubx/IndependentVoter}}
# |-
# | {{User:Libertyville/ProLife}}
# | {{User:StuffOfInterest/Userboxes/User no death penalty}}
# | {{User:WebHamster/fucking}}
# |-
# | {{User:Scartol/Userboxes/nonviolence}}
# | {{User:Tedius Zanarukando/Userboxes/User cvg proponent}}
# | {{User:The Raven's Apprentice/Userboxes/User Against Censorship}}
# |-
# | {{User:Tedius Zanarukando/Userboxes/User region free}}
# | {{User:SpikeToronto/userboxes/No Political Correctness}}
# | {{User Citizen Media}}
# |-
# | {{User Sustainable Living}}
# | {{User Renewable Energy}}
# | {{User:Ash/Userboxes/Freecycle}}
# |-
# | {{User:Ash/Userboxes/Recycle}}
# | {{User:Ash/Userboxes/Regiving}}
# | {{User:Disavian/Userboxes/Public Transit}}
# |-
# | {{User:Wintran/Userboxes/Immigration}}
# | {{User:SpikeToronto/userboxes/Same sex marriage}}
# | {{User:Bluedenim/Drugs}}
# |-
# | {{User:Triadian/Userboxes/UN Reform}}
# | {{User:Djr xi/User bad EU}}
# | {{User:UBX/User Swiss direct democracy}}
# |-
# | {{User:DieWeisseRose/Userboxes/OneState}}
# | {{User:Triadian/Userboxes/Stable Iraq}}
# | {{User:MQDuck/userboxes/Right_To_Resist}}
# |-
# |
# | {{User:Sappho'd/Userboxes/Conspiracybutnoreptoids}}
# |
# |}
# {{clear}}
# {{collapse bottom}}
#
# {{collapse top|Music}}
# {| class="wikitable"
# | {{User:Scepia/all music}}
# | {{User:Eternal dragon/Userboxes/QueenBohemianRhapsody}}
# | {{User:DannyQuack/Userboxes/Switchfoot}}
# |-
# | {{User:UBX/ColdPlay}}
# | {{User:UBX/Evanescence}}
# | {{User:UBX/REM}}
# |-
# | {{User:UBX/User Weird Al 2}}
# | {{User:UBX/don't wanna}}
# | {{Template: User LP}}
# |-
# | {{User Iron Man}}
# | {{User Enter Sandman}}
# | {{User Closer (Nine Inch Nails song)}}
# |-
# | {{User:UBX/NC}}
# | {{User:UBX/Beach Boys}}
# | {{User:UBX/Beatles}}
# |-
# | {{Template:User notslim}}
# | {{User:UBX/Tom Waits}}
# | {{User:Pokerdance/Lady Gaga fan}}
# |-
# | {{User:Tuzapicabit/Userboxes/Dancing Queen}}
# | {{User:Scepia/CVG music}}
# | {{User:The Arbiter/UBX/Love Story}}
#
# |}
# {{clear}}
# {{collapse bottom}}
#
# {{collapse top|Science Fiction}}
# {| class="wikitable"
# |-
# | {{User:Fultron89/Userboxes/fultronmatrix}}
# | {{User:UBX/swpm}}
# | {{User:UBX/Rebel Alliance 2}}
# |-
# | {{User:Merond e/StarWars-truelight}}
# | {{User:UBX/Theforce}}
# | {{User:UBX/Chewbacca}}
# |}
# {{clear}}
# {{collapse bottom}}
#
# {{collapse top|Literature}}
# {| class="wikitable"
# |-
# | {{User:Chamal N/Userboxes/The hobbit}}
# | {{User:Royalguard11/userboxes/Tolkien}}
# | {{User:UBX/User LOTR}}
# |-
# | {{User:Scepia/Watchmen}}
# | {{User:UBX/Cthulhu}}
# | {{User:Mkdw/HGG}}
# |-
# | {{User:Jimmy da tuna/Userboxes/orgy-porgy}}
# | {{User:Twooars/Userboxes/Rules and agreement}}
# | {{User:Scepia/Orwell}}
# |}
# {{clear}}
# {{collapse bottom}}
#
# {{collapse top|Science and Philosophy}}
# {| class="wikitable"
# |-
# | {{User:UBX/Medieval spherical earth}}
# | {{User:P.B. Pilhet/UBX/Evolution}}
# | {{User:UBX/Religion}}
# |-
# | {{User:WebHamster/belief}}
# | {{User:Wintran/Userboxes/Belief respect}}
# | {{User:UBX/Meher Baba3}}
# |-
# |
# | {{User:The Devil's Advocate/trueskeptic}}
# |
# |}
# {{clear}}
# {{collapse bottom}}
# {{collapse top|Video Games}}
# {| class="wikitable"
# |-
# | {{User:Oxguy3/myboxes/favm-Yoshi}}
# | {{User:Llama man/Userboxes/Zelda}}
# | {{User:UBX/Assassin's Creed}}
# |}
# {{clear}}
# {{collapse bottom}}
# {{collapse top|Animé}}
# {| class="wikitable"
# |-
# | {{Wikipedia:WikiProject Anime and manga/Userbox/User anime-4}}
# | {{Wikipedia:WikiProject Anime and manga/Userbox/User sub}}
# | {{User:ISD/Userboxes/Gurren Lagann 2}}
# |-
# | {{User:Alexjohnc3/Userboxes/user Haruhiism}}
# | {{User:Averross/Puchu}}
# | {{Wikipedia:WikiProject Anime and manga/Userbox/User Samurai Champloo 2}}
# |-
# | {{Wikipedia:WikiProject Anime and manga/Userbox/User Ghostintheshell2}}
# | {{Wikipedia:WikiProject Anime and manga/Userbox/User GunslingerGirl}}
# | {{Wikipedia:WikiProject Anime and manga/Userbox/User Fruits Basket}}
# |-
# | {{Wikipedia:WikiProject Anime and manga/Userbox/User Oreimo watch}}
# | {{Wikipedia:WikiProject Anime and manga/Userbox/User One Piece}}
# | {{Wikipedia:WikiProject Anime and manga/Userbox/User Full Metal Panic}}
# |-
# | {{User:Dwscomet/My userbox creations/AttackonTitan}}
# | {{Wikipedia:WikiProject Anime and manga/Userbox/User Negima}}
# | {{User:The Devil's Advocate/RWBY}}
# |}
# {{collapse bottom}}
# </textarea>
#      <div class="templatesUsed">
#       <div class="mw-templatesUsedExplanation">
#        <p>
#         <span id="templatesused">
#          Pages transcluded onto the current version of this page
#          <span class="posteditwindowhelplinks">
#           (
#           <a href="/wiki/Wikipedia:Transclusion" title="Wikipedia:Transclusion">
#            help
#           </a>
#           )
#          </span>
#          :
#         </span>
#        </p>
#       </div>
#       <ul>
#        <li>
#         <a href="/wiki/User:Alexjohnc3/Userboxes/user_Haruhiism" title="User:Alexjohnc3/Userboxes/user Haruhiism">
#          User:Alexjohnc3/Userboxes/user Haruhiism
#         </a>
#         (
#         <a href="/w/index.php?title=User:Alexjohnc3/Userboxes/user_Haruhiism&amp;action=edit" title="User:Alexjohnc3/Userboxes/user Haruhiism">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:Ash/Userboxes/Freecycle" title="User:Ash/Userboxes/Freecycle">
#          User:Ash/Userboxes/Freecycle
#         </a>
#         (
#         <a href="/w/index.php?title=User:Ash/Userboxes/Freecycle&amp;action=edit" title="User:Ash/Userboxes/Freecycle">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:Ash/Userboxes/Recycle" title="User:Ash/Userboxes/Recycle">
#          User:Ash/Userboxes/Recycle
#         </a>
#         (
#         <a href="/w/index.php?title=User:Ash/Userboxes/Recycle&amp;action=edit" title="User:Ash/Userboxes/Recycle">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a class="mw-redirect" href="/wiki/User:Ash/Userboxes/Regiving" title="User:Ash/Userboxes/Regiving">
#          User:Ash/Userboxes/Regiving
#         </a>
#         (
#         <a class="mw-redirect" href="/w/index.php?title=User:Ash/Userboxes/Regiving&amp;action=edit" title="User:Ash/Userboxes/Regiving">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:Ashley_Y/Userbox/Agnostic" title="User:Ashley Y/Userbox/Agnostic">
#          User:Ashley Y/Userbox/Agnostic
#         </a>
#         (
#         <a href="/w/index.php?title=User:Ashley_Y/Userbox/Agnostic&amp;action=edit" title="User:Ashley Y/Userbox/Agnostic">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:Averross/Puchu" title="User:Averross/Puchu">
#          User:Averross/Puchu
#         </a>
#         (
#         <a href="/w/index.php?title=User:Averross/Puchu&amp;action=edit" title="User:Averross/Puchu">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:Bluedenim/Drugs" title="User:Bluedenim/Drugs">
#          User:Bluedenim/Drugs
#         </a>
#         (
#         <a href="/w/index.php?title=User:Bluedenim/Drugs&amp;action=edit" title="User:Bluedenim/Drugs">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:Boing!_said_Zebedee/Userboxes/User:noadmin" title="User:Boing! said Zebedee/Userboxes/User:noadmin">
#          User:Boing! said Zebedee/Userboxes/User:noadmin
#         </a>
#         (
#         <a href="/w/index.php?title=User:Boing!_said_Zebedee/Userboxes/User:noadmin&amp;action=edit" title="User:Boing! said Zebedee/Userboxes/User:noadmin">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a class="mw-redirect" href="/wiki/User:Boing!_said_Zebedee/Userboxes/noadmin" title="User:Boing! said Zebedee/Userboxes/noadmin">
#          User:Boing! said Zebedee/Userboxes/noadmin
#         </a>
#         (
#         <a class="mw-redirect" href="/w/index.php?title=User:Boing!_said_Zebedee/Userboxes/noadmin&amp;action=edit" title="User:Boing! said Zebedee/Userboxes/noadmin">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:CaseyPenk/UBX/VG/Music" title="User:CaseyPenk/UBX/VG/Music">
#          User:CaseyPenk/UBX/VG/Music
#         </a>
#         (
#         <a href="/w/index.php?title=User:CaseyPenk/UBX/VG/Music&amp;action=edit" title="User:CaseyPenk/UBX/VG/Music">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:Chamal_N/Userboxes/The_hobbit" title="User:Chamal N/Userboxes/The hobbit">
#          User:Chamal N/Userboxes/The hobbit
#         </a>
#         (
#         <a href="/w/index.php?title=User:Chamal_N/Userboxes/The_hobbit&amp;action=edit" title="User:Chamal N/Userboxes/The hobbit">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:Dailynetworks/ubx/IndependentVoter" title="User:Dailynetworks/ubx/IndependentVoter">
#          User:Dailynetworks/ubx/IndependentVoter
#         </a>
#         (
#         <a href="/w/index.php?title=User:Dailynetworks/ubx/IndependentVoter&amp;action=edit" title="User:Dailynetworks/ubx/IndependentVoter">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:DannyQuack/Userboxes/Switchfoot" title="User:DannyQuack/Userboxes/Switchfoot">
#          User:DannyQuack/Userboxes/Switchfoot
#         </a>
#         (
#         <a href="/w/index.php?title=User:DannyQuack/Userboxes/Switchfoot&amp;action=edit" title="User:DannyQuack/Userboxes/Switchfoot">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:DieWeisseRose/Userboxes/OneState" title="User:DieWeisseRose/Userboxes/OneState">
#          User:DieWeisseRose/Userboxes/OneState
#         </a>
#         (
#         <a href="/w/index.php?title=User:DieWeisseRose/Userboxes/OneState&amp;action=edit" title="User:DieWeisseRose/Userboxes/OneState">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:Disavian/Userboxes/Public_Transit" title="User:Disavian/Userboxes/Public Transit">
#          User:Disavian/Userboxes/Public Transit
#         </a>
#         (
#         <a href="/w/index.php?title=User:Disavian/Userboxes/Public_Transit&amp;action=edit" title="User:Disavian/Userboxes/Public Transit">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:Djr_xi/User_bad_EU" title="User:Djr xi/User bad EU">
#          User:Djr xi/User bad EU
#         </a>
#         (
#         <a href="/w/index.php?title=User:Djr_xi/User_bad_EU&amp;action=edit" title="User:Djr xi/User bad EU">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:Dwscomet/My_userbox_creations/AttackonTitan" title="User:Dwscomet/My userbox creations/AttackonTitan">
#          User:Dwscomet/My userbox creations/AttackonTitan
#         </a>
#         (
#         <a href="/w/index.php?title=User:Dwscomet/My_userbox_creations/AttackonTitan&amp;action=edit" title="User:Dwscomet/My userbox creations/AttackonTitan">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:Eternal_dragon/Userboxes/QueenBohemianRhapsody" title="User:Eternal dragon/Userboxes/QueenBohemianRhapsody">
#          User:Eternal dragon/Userboxes/QueenBohemianRhapsody
#         </a>
#         (
#         <a href="/w/index.php?title=User:Eternal_dragon/Userboxes/QueenBohemianRhapsody&amp;action=edit" title="User:Eternal dragon/Userboxes/QueenBohemianRhapsody">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a class="mw-redirect" href="/wiki/User:Feureau/UserBox/ubx-5" title="User:Feureau/UserBox/ubx-5">
#          User:Feureau/UserBox/ubx-5
#         </a>
#         (
#         <a class="mw-redirect" href="/w/index.php?title=User:Feureau/UserBox/ubx-5&amp;action=edit" title="User:Feureau/UserBox/ubx-5">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:Fultron89/Userboxes/fultronmatrix" title="User:Fultron89/Userboxes/fultronmatrix">
#          User:Fultron89/Userboxes/fultronmatrix
#         </a>
#         (
#         <a href="/w/index.php?title=User:Fultron89/Userboxes/fultronmatrix&amp;action=edit" title="User:Fultron89/Userboxes/fultronmatrix">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:Gordalmighty/Userbox/Ron_Paul" title="User:Gordalmighty/Userbox/Ron Paul">
#          User:Gordalmighty/Userbox/Ron Paul
#         </a>
#         (
#         <a href="/w/index.php?title=User:Gordalmighty/Userbox/Ron_Paul&amp;action=edit" title="User:Gordalmighty/Userbox/Ron Paul">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:Hmwith/ubx/male" title="User:Hmwith/ubx/male">
#          User:Hmwith/ubx/male
#         </a>
#         (
#         <a href="/w/index.php?title=User:Hmwith/ubx/male&amp;action=edit" title="User:Hmwith/ubx/male">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:ISD/Userboxes/Gurren_Lagann_2" title="User:ISD/Userboxes/Gurren Lagann 2">
#          User:ISD/Userboxes/Gurren Lagann 2
#         </a>
#         (
#         <a href="/w/index.php?title=User:ISD/Userboxes/Gurren_Lagann_2&amp;action=edit" title="User:ISD/Userboxes/Gurren Lagann 2">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:J.P.Lon/Userboxes/Interest-Economics" title="User:J.P.Lon/Userboxes/Interest-Economics">
#          User:J.P.Lon/Userboxes/Interest-Economics
#         </a>
#         (
#         <a href="/w/index.php?title=User:J.P.Lon/Userboxes/Interest-Economics&amp;action=edit" title="User:J.P.Lon/Userboxes/Interest-Economics">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:JLogan/LesSym" title="User:JLogan/LesSym">
#          User:JLogan/LesSym
#         </a>
#         (
#         <a href="/w/index.php?title=User:JLogan/LesSym&amp;action=edit" title="User:JLogan/LesSym">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:Jer10_95/privatename" title="User:Jer10 95/privatename">
#          User:Jer10 95/privatename
#         </a>
#         (
#         <a href="/w/index.php?title=User:Jer10_95/privatename&amp;action=edit" title="User:Jer10 95/privatename">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:Jimmy_da_tuna/Userboxes/orgy-porgy" title="User:Jimmy da tuna/Userboxes/orgy-porgy">
#          User:Jimmy da tuna/Userboxes/orgy-porgy
#         </a>
#         (
#         <a href="/w/index.php?title=User:Jimmy_da_tuna/Userboxes/orgy-porgy&amp;action=edit" title="User:Jimmy da tuna/Userboxes/orgy-porgy">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a class="mw-redirect" href="/wiki/User:JohnRussell/wikipedianumedits" title="User:JohnRussell/wikipedianumedits">
#          User:JohnRussell/wikipedianumedits
#         </a>
#         (
#         <a class="mw-redirect" href="/w/index.php?title=User:JohnRussell/wikipedianumedits&amp;action=edit" title="User:JohnRussell/wikipedianumedits">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:Libertyville/ProLife" title="User:Libertyville/ProLife">
#          User:Libertyville/ProLife
#         </a>
#         (
#         <a href="/w/index.php?title=User:Libertyville/ProLife&amp;action=edit" title="User:Libertyville/ProLife">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a class="mw-redirect" href="/wiki/User:Llama_man/Userboxes/Zelda" title="User:Llama man/Userboxes/Zelda">
#          User:Llama man/Userboxes/Zelda
#         </a>
#         (
#         <a class="mw-redirect" href="/w/index.php?title=User:Llama_man/Userboxes/Zelda&amp;action=edit" title="User:Llama man/Userboxes/Zelda">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:MQDuck/userboxes/Right_To_Resist" title="User:MQDuck/userboxes/Right To Resist">
#          User:MQDuck/userboxes/Right To Resist
#         </a>
#         (
#         <a href="/w/index.php?title=User:MQDuck/userboxes/Right_To_Resist&amp;action=edit" title="User:MQDuck/userboxes/Right To Resist">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:Malcolm/Userboxes/Zelda" title="User:Malcolm/Userboxes/Zelda">
#          User:Malcolm/Userboxes/Zelda
#         </a>
#         (
#         <a href="/w/index.php?title=User:Malcolm/Userboxes/Zelda&amp;action=edit" title="User:Malcolm/Userboxes/Zelda">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:Menasim/Userboxes/User_quote" title="User:Menasim/Userboxes/User quote">
#          User:Menasim/Userboxes/User quote
#         </a>
#         (
#         <a href="/w/index.php?title=User:Menasim/Userboxes/User_quote&amp;action=edit" title="User:Menasim/Userboxes/User quote">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:Merond_e/StarWars-truelight" title="User:Merond e/StarWars-truelight">
#          User:Merond e/StarWars-truelight
#         </a>
#         (
#         <a href="/w/index.php?title=User:Merond_e/StarWars-truelight&amp;action=edit" title="User:Merond e/StarWars-truelight">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:Mkdw/HGG" title="User:Mkdw/HGG">
#          User:Mkdw/HGG
#         </a>
#         (
#         <a href="/w/index.php?title=User:Mkdw/HGG&amp;action=edit" title="User:Mkdw/HGG">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:Oxguy3/myboxes/favm-Yoshi" title="User:Oxguy3/myboxes/favm-Yoshi">
#          User:Oxguy3/myboxes/favm-Yoshi
#         </a>
#         (
#         <a href="/w/index.php?title=User:Oxguy3/myboxes/favm-Yoshi&amp;action=edit" title="User:Oxguy3/myboxes/favm-Yoshi">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:P.B._Pilhet/UBX/Evolution" title="User:P.B. Pilhet/UBX/Evolution">
#          User:P.B. Pilhet/UBX/Evolution
#         </a>
#         (
#         <a href="/w/index.php?title=User:P.B._Pilhet/UBX/Evolution&amp;action=edit" title="User:P.B. Pilhet/UBX/Evolution">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a class="mw-redirect" href="/wiki/User:Pokerdance/Lady_Gaga_fan" title="User:Pokerdance/Lady Gaga fan">
#          User:Pokerdance/Lady Gaga fan
#         </a>
#         (
#         <a class="mw-redirect" href="/w/index.php?title=User:Pokerdance/Lady_Gaga_fan&amp;action=edit" title="User:Pokerdance/Lady Gaga fan">
#          edit
#         </a>
#         )
#        </li>
#        <li>
#         <a href="/wiki/User:Pokerdance/Userboxes/Lady_Gaga_fan" title="User:Pokerdance/Userboxes/Lady Gaga fan">
#          User:Pokerdance/Userboxes/Lady Gaga fan
#         </a>
#         (
# ...
#          view source
#         </a>
#         ) (template protected)
#        </li>
#        <li>
#         <a href="/wiki/Module:Icon/data" title="Module:Icon/data">
#          Module:Icon/data
#         </a>
#         (
#         <a href="/w/index.php?title=Module:Icon/data&amp;action=edit" title="Module:Icon/data">
#          view source
#         </a>
#         ) (template protected)
#        </li>
#        <li>
#         <a href="/wiki/Module:Labelled_list_hatnote" title="Module:Labelled list hatnote">
#          Module:Labelled list hatnote
#         </a>
#         (
#         <a href="/w/index.php?title=Module:Labelled_list_hatnote&amp;action=edit" title="Module:Labelled list hatnote">
#          view source
#         </a>
#         ) (template protected)
#        </li>
#        <li>
#         <a href="/wiki/Module:Message_box" title="Module:Message box">
#          Module:Message box
#         </a>
#         (
#         <a href="/w/index.php?title=Module:Message_box&amp;action=edit" title="Module:Message box">
#          view source
#         </a>
#         ) (protected)
#        </li>
#        <li>
#         <a href="/wiki/Module:Message_box/configuration" title="Module:Message box/configuration">
#          Module:Message box/configuration
#         </a>
#         (
#         <a href="/w/index.php?title=Module:Message_box/configuration&amp;action=edit" title="Module:Message box/configuration">
#          view source
#         </a>
#         ) (protected)
#        </li>
#        <li>
#         <a href="/wiki/Module:Namespace_detect/config" title="Module:Namespace detect/config">
#          Module:Namespace detect/config
#         </a>
#         (
#         <a href="/w/index.php?title=Module:Namespace_detect/config&amp;action=edit" title="Module:Namespace detect/config">
#          view source
#         </a>
#         ) (protected)
#        </li>
#        <li>
#         <a href="/wiki/Module:Namespace_detect/data" title="Module:Namespace detect/data">
#          Module:Namespace detect/data
#         </a>
#         (
#         <a href="/w/index.php?title=Module:Namespace_detect/data&amp;action=edit" title="Module:Namespace detect/data">
#          view source
#         </a>
#         ) (protected)
#        </li>
#        <li>
#         <a href="/wiki/Module:No_globals" title="Module:No globals">
#          Module:No globals
#         </a>
#         (
#         <a href="/w/index.php?title=Module:No_globals&amp;action=edit" title="Module:No globals">
#          view source
#         </a>
#         ) (template protected)
#        </li>
#        <li>
#         <a href="/wiki/Module:Protection_banner" title="Module:Protection banner">
#          Module:Protection banner
#         </a>
#         (
#         <a href="/w/index.php?title=Module:Protection_banner&amp;action=edit" title="Module:Protection banner">
#          view source
#         </a>
#         ) (template protected)
#        </li>
#        <li>
#         <a href="/wiki/Module:Protection_banner/config" title="Module:Protection banner/config">
#          Module:Protection banner/config
#         </a>
#         (
#         <a href="/w/index.php?title=Module:Protection_banner/config&amp;action=edit" title="Module:Protection banner/config">
#          view source
#         </a>
#         ) (protected)
#        </li>
#        <li>
#         <a href="/wiki/Module:Userbox" title="Module:Userbox">
#          Module:Userbox
#         </a>
#         (
#         <a href="/w/index.php?title=Module:Userbox&amp;action=edit" title="Module:Userbox">
#          view source
#         </a>
#         ) (template protected)
#        </li>
#        <li>
#         <a href="/wiki/Module:Yesno" title="Module:Yesno">
#          Module:Yesno
#         </a>
#         (
#         <a href="/w/index.php?title=Module:Yesno&amp;action=edit" title="Module:Yesno">
#          view source
#         </a>
#         ) (protected)
#        </li>
#       </ul>
#      </div>
#      <p id="mw-returnto">
#       Return to
#       <a href="/wiki/User:The_Devil%27s_Advocate" title="User:The Devil's Advocate">
#        User:The Devil's Advocate
#       </a>
#       .
#      </p>
#      <noscript>
#       <img alt="" height="1" src="//en.wikipedia.org/wiki/Special:CentralAutoLogin/start?type=1x1" style="border: none; position: absolute;" title="" width="1"/>
#      </noscript>
#     </div>
#     <div class="printfooter">
#      Retrieved from "
#      <a dir="ltr" href="https://en.wikipedia.org/wiki/User:The_Devil%27s_Advocate">
#       https://en.wikipedia.org/wiki/User:The_Devil%27s_Advocate
#      </a>
#      "
#     </div>
#     <div class="catlinks catlinks-allhidden" data-mw="interface" id="catlinks">
#     </div>
#     <div class="visualClear">
#     </div>
#    </div>
#   </div>
#   <div id="mw-navigation">
#    <h2>
#     Navigation menu
#    </h2>
#    <div id="mw-head">
#     <div aria-labelledby="p-personal-label" class="" id="p-personal" role="navigation">
#      <h3 id="p-personal-label">
#       Personal tools
#      </h3>
#      <ul>
#       <li id="pt-anonuserpage">
#        Not logged in
#       </li>
#       <li id="pt-anontalk">
#        <a accesskey="n" href="/wiki/Special:MyTalk" title="Discussion about edits from this IP address [n]">
#         Talk
#        </a>
#       </li>
#       <li id="pt-anoncontribs">
#        <a accesskey="y" href="/wiki/Special:MyContributions" title="A list of edits made from this IP address [y]">
#         Contributions
#        </a>
#       </li>
#       <li id="pt-createaccount">
#        <a href="/w/index.php?title=Special:CreateAccount&amp;returnto=User%3AThe+Devil%27s+Advocate&amp;returntoquery=action%3Dedit" title="You are encouraged to create an account and log in; however, it is not mandatory">
#         Create account
#        </a>
#       </li>
#       <li id="pt-login">
#        <a accesskey="o" href="/w/index.php?title=Special:UserLogin&amp;returnto=User%3AThe+Devil%27s+Advocate&amp;returntoquery=action%3Dedit" title="You're encouraged to log in; however, it's not mandatory. [o]">
#         Log in
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div id="left-navigation">
#      <div aria-labelledby="p-namespaces-label" class="vectorTabs" id="p-namespaces" role="navigation">
#       <h3 id="p-namespaces-label">
#        Namespaces
#       </h3>
#       <ul>
#        <li class="selected" id="ca-nstab-user">
#         <span>
#          <a accesskey="c" href="/wiki/User:The_Devil%27s_Advocate" title="View the user page [c]">
#           User page
#          </a>
#         </span>
#        </li>
#        <li id="ca-talk">
#         <span>
#          <a accesskey="t" href="/wiki/User_talk:The_Devil%27s_Advocate" rel="discussion" title="Discussion about the content page [t]">
#           Talk
#          </a>
#         </span>
#        </li>
#       </ul>
#      </div>
#      <div aria-labelledby="p-variants-label" class="vectorMenu emptyPortlet" id="p-variants" role="navigation">
#       <input aria-labelledby="p-variants-label" class="vectorMenuCheckbox" type="checkbox"/>
#       <h3 id="p-variants-label">
#        <span>
#         Variants
#        </span>
#       </h3>
#       <div class="menu">
#        <ul>
#        </ul>
#       </div>
#      </div>
#     </div>
#     <div id="right-navigation">
#      <div aria-labelledby="p-views-label" class="vectorTabs" id="p-views" role="navigation">
#       <h3 id="p-views-label">
#        Views
#       </h3>
#       <ul>
#        <li class="collapsible" id="ca-view">
#         <span>
#          <a href="/wiki/User:The_Devil%27s_Advocate">
#           Read
#          </a>
#         </span>
#        </li>
#        <li class="collapsible selected" id="ca-viewsource">
#         <span>
#          <a accesskey="e" href="/w/index.php?title=User:The_Devil%27s_Advocate&amp;action=edit" title="This page is protected.
# You can view its source [e]">
#           View source
#          </a>
#         </span>
#        </li>
#        <li class="collapsible" id="ca-history">
#         <span>
#          <a accesskey="h" href="/w/index.php?title=User:The_Devil%27s_Advocate&amp;action=history" title="Past revisions of this page [h]">
#           View history
#          </a>
#         </span>
#        </li>
#       </ul>
#      </div>
#      <div aria-labelledby="p-cactions-label" class="vectorMenu emptyPortlet" id="p-cactions" role="navigation">
#       <input aria-labelledby="p-cactions-label" class="vectorMenuCheckbox" type="checkbox"/>
#       <h3 id="p-cactions-label">
#        <span>
#         More
#        </span>
#       </h3>
#       <div class="menu">
#        <ul>
#        </ul>
#       </div>
#      </div>
#      <div id="p-search" role="search">
#       <h3>
#        <label for="searchInput">
#         Search
#        </label>
#       </h3>
#       <form action="/w/index.php" id="searchform">
#        <div id="simpleSearch">
#         <input accesskey="f" id="searchInput" name="search" placeholder="Search Wikipedia" title="Search Wikipedia [f]" type="search"/>
#         <input name="title" type="hidden" value="Special:Search"/>
#         <input class="searchButton mw-fallbackSearchButton" id="mw-searchButton" name="fulltext" title="Search Wikipedia for this text" type="submit" value="Search"/>
#         <input class="searchButton" id="searchButton" name="go" title="Go to a page with this exact name if it exists" type="submit" value="Go"/>
#        </div>
#       </form>
#      </div>
#     </div>
#    </div>
#    <div id="mw-panel">
#     <div id="p-logo" role="banner">
#      <a class="mw-wiki-logo" href="/wiki/Main_Page" title="Visit the main page">
#      </a>
#     </div>
#     <div aria-labelledby="p-navigation-label" class="portal" id="p-navigation" role="navigation">
#      <h3 id="p-navigation-label">
#       Navigation
#      </h3>
#      <div class="body">
#       <ul>
#        <li id="n-mainpage-description">
#         <a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]">
#          Main page
#         </a>
#        </li>
#        <li id="n-contents">
#         <a href="/wiki/Portal:Contents" title="Guides to browsing Wikipedia">
#          Contents
#         </a>
#        </li>
#        <li id="n-featuredcontent">
#         <a href="/wiki/Portal:Featured_content" title="Featured content – the best of Wikipedia">
#          Featured content
#         </a>
#        </li>
#        <li id="n-currentevents">
#         <a href="/wiki/Portal:Current_events" title="Find background information on current events">
#          Current events
#         </a>
#        </li>
#        <li id="n-randompage">
#         <a accesskey="x" href="/wiki/Special:Random" title="Load a random article [x]">
#          Random article
#         </a>
#        </li>
#        <li id="n-sitesupport">
#         <a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us">
#          Donate to Wikipedia
#         </a>
#        </li>
#        <li id="n-shoplink">
#         <a href="//shop.wikimedia.org" title="Visit the Wikipedia store">
#          Wikipedia store
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div aria-labelledby="p-interaction-label" class="portal" id="p-interaction" role="navigation">
#      <h3 id="p-interaction-label">
#       Interaction
#      </h3>
#      <div class="body">
#       <ul>
#        <li id="n-help">
#         <a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia">
#          Help
#         </a>
#        </li>
#        <li id="n-aboutsite">
#         <a href="/wiki/Wikipedia:About" title="Find out about Wikipedia">
#          About Wikipedia
#         </a>
#        </li>
#        <li id="n-portal">
#         <a href="/wiki/Wikipedia:Community_portal" title="About the project, what you can do, where to find things">
#          Community portal
#         </a>
#        </li>
#        <li id="n-recentchanges">
#         <a accesskey="r" href="/wiki/Special:RecentChanges" title="A list of recent changes in the wiki [r]">
#          Recent changes
#         </a>
#        </li>
#        <li id="n-contactpage">
#         <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia">
#          Contact page
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div aria-labelledby="p-tb-label" class="portal" id="p-tb" role="navigation">
#      <h3 id="p-tb-label">
#       Tools
#      </h3>
#      <div class="body">
#       <ul>
#        <li id="t-whatlinkshere">
#         <a accesskey="j" href="/wiki/Special:WhatLinksHere/User:The_Devil%27s_Advocate" title="List of all English Wikipedia pages containing links to this page [j]">
#          What links here
#         </a>
#        </li>
#        <li id="t-recentchangeslinked">
#         <a accesskey="k" href="/wiki/Special:RecentChangesLinked/User:The_Devil%27s_Advocate" rel="nofollow" title="Recent changes in pages linked from this page [k]">
#          Related changes
#         </a>
#        </li>
#        <li id="t-contributions">
#         <a href="/wiki/Special:Contributions/The_Devil%27s_Advocate" title="A list of contributions by this user">
#          User contributions
#         </a>
#        </li>
#        <li id="t-log">
#         <a href="/wiki/Special:Log/The_Devil%27s_Advocate" title="View the list of actions by this user">
#          Logs
#         </a>
#        </li>
#        <li id="t-userrights">
#         <a href="/wiki/Special:UserRights/The_Devil%27s_Advocate">
#          View user groups
#         </a>
#        </li>
#        <li id="t-upload">
#         <a accesskey="u" href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]">
#          Upload file
#         </a>
#        </li>
#        <li id="t-specialpages">
#         <a accesskey="q" href="/wiki/Special:SpecialPages" title="A list of all special pages [q]">
#          Special pages
#         </a>
#        </li>
#        <li id="t-info">
#         <a href="/w/index.php?title=User:The_Devil%27s_Advocate&amp;action=info" title="More information about this page">
#          Page information
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div aria-labelledby="p-lang-label" class="portal" id="p-lang" role="navigation">
#      <h3 id="p-lang-label">
#       Languages
#      </h3>
#      <div class="body">
#       <ul>
#       </ul>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div id="footer" role="contentinfo">
#    <ul id="footer-places">
#     <li id="footer-places-privacy">
#      <a class="extiw" href="https://wikimediafoundation.org/wiki/Privacy_policy" title="wmf:Privacy policy">
#       Privacy policy
#      </a>
#     </li>
#     <li id="footer-places-about">
#      <a href="/wiki/Wikipedia:About" title="Wikipedia:About">
#       About Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-disclaimer">
#      <a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">
#       Disclaimers
#      </a>
#     </li>
#     <li id="footer-places-contact">
#      <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">
#       Contact Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-developers">
#      <a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">
#       Developers
#      </a>
#     </li>
#     <li id="footer-places-cookiestatement">
#      <a href="https://wikimediafoundation.org/wiki/Cookie_statement">
#       Cookie statement
#      </a>
#     </li>
#     <li id="footer-places-mobileview">
#      <a class="noprint stopMobileRedirectToggle" href="//en.m.wikipedia.org/w/index.php?title=User:The_Devil%27s_Advocate&amp;action=edit&amp;mobileaction=toggle_view_mobile">
#       Mobile view
#      </a>
#     </li>
#    </ul>
#    <ul class="noprint" id="footer-icons">
#     <li id="footer-copyrightico">
#      <a href="https://wikimediafoundation.org/">
#       <img alt="Wikimedia Foundation" height="31" src="/static/images/wikimedia-button.png" srcset="/static/images/wikimedia-button-1.5x.png 1.5x, /static/images/wikimedia-button-2x.png 2x" width="88"/>
#      </a>
#     </li>
#     <li id="footer-poweredbyico">
#      <a href="//www.mediawiki.org/">
#       <img alt="Powered by MediaWiki" height="31" src="/static/images/poweredby_mediawiki_88x31.png" srcset="/static/images/poweredby_mediawiki_132x47.png 1.5x, /static/images/poweredby_mediawiki_176x62.png 2x" width="88"/>
#      </a>
#     </li>
#    </ul>
#    <div style="clear: both;">
#    </div>
#   </div>
#   <script>
#    (window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":310,"wgHostname":"mw1242"});});
#   </script>
#  </body>
# </html>

# %%
source = soup.find('textarea')

from pprint import pprint

pprint(source.text)
# Out:
# ("{{pp-protected|reason=gravedancing and edit warring over a freakin' user "
#  'page|small=yes}}\n'
#  '\n'
#  '{{banned|by=the [[WP:AC|Arbitration '
#  "Committee]]|link=[[Special:Permalink/697679352#The Devil's Advocate "
#  'banned|announcement]]}}\n'
#  '{{banned user}}\n'
#  '{{reviewer topicon|icon_nr=1}}\n'
#  '{{Rollback topicon|icon_nr=2}} \n'
#  '{{user new message}}\n'
#  '\n'
#  "{{Userboxtop|The Devil's Advocate|bordercolor=#000000}}\n"
#  '{{User:Jer10 95/privatename}}\n'
#  '{{user:hmwith/ubx/male}}\n'
#  '{{User:UserBox/User Earthling}}\n'
#  '{{user en}}\n'
#  '{{User:Ashley Y/Userbox/Agnostic}}\n'
#  '{{User:UBX/girlfriendwish}}\n'
#  '{{User:JLogan/LesSym}}\n'
#  '{{User:UBX/Coke Pepsi}}\n'
#  '{{Template:user ancestry multi}}\n'
#  '{{Template:User Immortal}}\n'
#  '{{User Wikimedia Commons}}\n'
#  '{{userbox\n'
#  '|id=[[File:Box-cutter.jpg|50px]]\n'
#  "|info=This user reads '''[[Wikipediocracy]]'''\n"
#  '}}\n'
#  '{{User:Boing! said Zebedee/Userboxes/noadmin}}\n'
#  '{{User:UBX/Twinkle4}}\n'
#  '{{User wikipedia/WikiDragon2}}\n'
#  '{{User edit}}\n'
#  '{{User recursively neutral}}\n'
#  '{{User:SpeakFree/no barnstar}}\n'
#  '{{Template:User WikiPeace}}\n'
#  '{{User:Running/wikipe-tan}}\n'
#  '{{User:JohnRussell/wikipedianumedits|19,000}}\n'
#  '{{User:Timeastor/personality versatile}}\n'
#  '{{User:Menasim/Userboxes/User quote|"All men can be criminals, if tempted; '
#  'all men can be heroes, if inspired."\n'
#  '|G. K. Chesterton}}\n'
#  '{{User:Scepia/beauty}}\n'
#  '{{User:Scepia/HDTV}}\n'
#  '{{User:Feureau/UserBox/ubx-5}}\n'
#  '{{Userboxbottom}}\n'
#  '<div>\n'
#  '<center>\n'
#  '<div style=" padding:0px; margin:0px;background:#ffffff; border-top:1px '
#  'solid #ff9933; border-left:1px solid #ff9933; border-right:1px solid '
#  '#ff9933;">\n'
#  "<center>[[Special:Contributions/The Devil's Advocate|Contributions]] | "
#  "[[User:The Devil's Advocate/Sandbox|Sand Box]] | [[User:The Devil's "
#  "Advocate/drafts|Drafts]] | [[User:The Devil's Advocate/Links|Links]]| "
#  "[[User:The Devil's Advocate/GeneralMusings|General Musings]]</center></div>\n"
#  '<div style=" padding:0px; margin-bottom:5px;background:#eee; '
#  'border-bottom:1px solid #ccc;border-left:1px solid #ccc; border-right:1px '
#  'solid #ccc;">\n'
#  '</div>\n'
#  '</center>\n'
#  '</div>\n'
#  '\n'
#  '[[File:Uncle Wikipe-tan.png|600px]]\n'
#  '\n'
#  '==About me==\n'
#  'My first foray into editing Wikipedia was updating the article on the '
#  "[[Six-party talks]] over North Korea's nuclear weapons program. Gradually, I "
#  'moved into editing about regional unions and other political topics, such as '
#  'the 2008 U.S. Presidential primaries and articles about geopolitical '
#  'developments. This included my first trial by fire when a geopolitics '
#  'article I created wound up at Articles for Deletion due to a rather poor '
#  'naming choice on my part. On several occasions during my time editing here I '
#  'have become so disenchanted with the flaws in the process that it prompted '
#  'lulls in my editing with the most recent one having been for a couple of '
#  'months and the longest one being for about a year. In the past two years I '
#  'have diversified my content contributions to focus less on politics, which '
#  'has often proven too stressful for an enjoyable editing experience.\n'
#  '\n'
#  'Although I started out being mostly interested in contributing content, the '
#  'various situations I have confronted on Wikipedia have prompted me to show a '
#  "more general concern over this site's culture and governance. I have been "
#  'involved in the Wikipedia criticism site [[Wikipediocracy]] for over two '
#  'years because of this, although anyone there can tell you of the many times '
#  'when I am not on their side either. My concerns about Wikipedia also mean I '
#  'was more of a regular on various conduct noticeboards and sometimes weighed '
#  'in on [[Wikipedia:Arbitration|arbitration]] matters until I took '
#  '[[Wikipedia:Arbitration/Requests/Case/GamerGate|an arbitration case]] to the '
#  'knee. Typically, I only become involved when I notice a particular problem '
#  'is not being discussed or feel one or more editors are being treated '
#  'unfairly.\n'
#  '\n'
#  'In addition to my contributions on the Wikimedia projects, I have become '
#  'fairly active on the '
#  '[http://rwby.wikia.com/wiki/User:The_Devil%27s_Advocate_WP RWBY Wiki] hosted '
#  'by Wikia. Outside my involvement with wikis, my time on the Internet is '
#  'mostly spent doing typical Internet things of no consequence. During my time '
#  'off-line I similarly do things of little consequence and am generally a '
#  'person of no consequence to anyone, even in my humble rural community, '
#  'though as [[Revolution (Beatles song)|the song]] goes "we all want to change '
#  'the world" and I do hope I could have a realistic chance at that one day.\n'
#  '== My editing philosophy ==\n'
#  '\n'
#  'In my editing I strive to take the approach of a [[Bohemianism|Bohemian]] '
#  'Wikipedian. I draw my inspiration from the values espoused in the film '
#  '[[Moulin Rouge!]] of [[Truth]], [[Beauty]], [[Liberty|Freedom]], and '
#  '[[Love]]. These also reflect the kind of values I try to uphold in life. As '
#  'it pertains to Wikipedia I apply these values in this way:\n'
#  '\n'
#  "*'''Truth''' - Far too often people take the dictum of [[WP:V|verifiability, "
#  'not truth]] too far by presuming that if a reliable source can be found to '
#  'make the claim then it is ok for Wikipedia to say it in the editorial voice. '
#  "Usually this occurs because of an editor's own bias seeping into his or her "
#  'editing process. At times because there is an absence of contravening '
#  'sources editors similarly feel confident in using stronger language than '
#  'that of their sources. However, I believe this goes against an unspoken rule '
#  'that Wikipedia should always strive for factual accuracy. I seek to counter '
#  'the [[systemic bias]] that often works its way into contentious topic areas '
#  'in pursuit of the greater truth. That means using the most '
#  '[[WP:NPOV|neutral]] wording the sources support and, save for "[[WP:BLUE|sky '
#  'is blue]]"-type situations, [[WP:INTEXT|in-text attribution]] should be the '
#  'norm. The goal is making the project a place to find the whole story with '
#  'eyes unclouded by prejudice, contrary to the more controlled sources of '
#  'information in the world.\n'
#  "*'''Beauty''' - When it comes to any article one is likely to find more than "
#  'a few instances of repetition and less-than-engaging wording. One of my '
#  'objectives in contributing to Wikipedia is to improve the stylistic '
#  'appearance of any article I come across. That means, to provide an example, '
#  'trimming down the instances of paragraphs starting with the same letter, and '
#  'especially the same word. Another big issue is avoiding the timeline-like '
#  'style certain articles about ongoing events tend to take on out of a general '
#  'apathy of editors. By beautifying the project wherever I can my hope is that '
#  'more readers will be engaged with the repository of knowledge Wikipedia '
#  'represents.\n'
#  "*'''Freedom''' - This project is first and foremost an experiment in "
#  'information democracy. Submitting the whole of human ingenuity and knowledge '
#  'to the task of building a source of knowledge for all requires great care '
#  'and consideration. As predicted by the [[iron law of oligarchy]], Wikipedia '
#  'has fallen prey to the same abusive tendencies of any governance system. '
#  'Rule by [[consensus]] may appear to be a policy to cherish, but it is all '
#  'too often misused by editors to impose their own will on the project. '
#  '[[WP:AGF|Assuming good faith]] keeps us willfully blind to some extent about '
#  'what is taking place. Look through any article in a contentious topic area '
#  'and you are liable to find a consortium of editors from the same ideological '
#  "persuasion who have become the page's self-appointed gatekeepers. "
#  'Enterprising users who go against their will often find themselves driven '
#  'away, whether it is by falling into a [[WP:edit war|revert trap]] or simply '
#  'becoming frustrated with endless [[WP:STONEWALL|stone-walling]]. '
#  'Unfortunately, Wikipedia looks more favorably upon the gatekeepers as they '
#  'greatly outnumber their opponent. Always looking for a way to satisfy all '
#  'parties without compromising my principles and drawing attention to the '
#  'biases of all sides is the best way I can think of to insure this experiment '
#  'remains open to as many people as possible.\n'
#  "*'''Love''' - Above all things I believe in [[WP:WikiLove|WikiLove]]. [[Love "
#  'is Like Oxygen|WikiLove is like oxygen]]. [[Up Where We Belong|WikiLove '
#  'lifts us up where we belong]]. [[All You Need Is Love|All you need is '
#  'WikiLove]]. For me it means keeping an open mind on all things. Were more '
#  'editors to leave themselves open it would be easier to defuse most disputes. '
#  'Remain open to having your edits rewritten. Remain open to changing your '
#  "mind. Remain open to changing your actions even if you won't change your "
#  'mind. Too much potential is lost in the ideological rigidity of '
#  '[[groupthink]] and [[confirmation bias]]. Pursuit of WikiLove means that the '
#  'only things we should try to take seriously are the feelings of others. '
#  'Sometimes it is hard to [[WP:COOL|stay cool]] and we have all been there at '
#  'one point or another. We should thus [[User:Heimstern/Ignoring '
#  "incivility|not let an occasional lapse]] determine someone's fate as none of "
#  'us are perfect. Keep in mind that we do this not for ourselves, but for all '
#  'those who may witness this body of work.\n'
#  '\n'
#  'To sum it all up, my goal is to try and uphold the idea of what Wikipedia '
#  'can be, while dealing with the reality of what Wikipedia is at this moment. '
#  'More than anything I want this project to be a great service to all '
#  'truth-seekers in the world. It should be a light of knowledge in dark places '
#  'when all other lights go out. One could say that I am a true believer when '
#  'it comes to this idea and, even if it leaves me battered and bruised, I will '
#  'strive to defend the principles of this project above all else.\n'
#  '\n'
#  '== Things to do ==\n'
#  "{{See also|User:The Devil's Advocate/List of priority articles|label 1=List "
#  'of priority articles}}\n'
#  '{{col-begin}}\n'
#  '| width="50%" align="{{{align|left}}}" valign="{{{valign|top}}}" '
#  'style="border:0"|\n'
#  '*Create article on [[E*Trade]] baby.\n'
#  '*Turn [[Wikipedia:Inaccuracy]] into a fitting proposal for a guideline.\n'
#  '*Write essay on "camping" at articles.\n'
#  '*Write essay on "railroading" by groups to potentially link with camping.\n'
#  '*Write essay on "echo chamber" to discuss [[groupthink]] on Wikipedia to '
#  'link from camping and railroading.\n'
#  '*Write essay on "doubling down" in contentious disputes.\n'
#  '*Create article on Consolidated Restaurant Operations for possible merge '
#  'with [[Dixie House]] article.\n'
#  '*Create article on WiseGeek.\n'
#  '*Expand article on [[Google Panda]] and [[content farm]].\n'
#  '*Create article on Caroline Rose Hunt.\n'
#  '*Create article on Maritz, Wolff & Co.\n'
#  '*Create article on Sheppard King.\n'
#  '*Create article on Americas Lodging Investment Summit.\n'
#  '*Expand [[AAA Five Diamond Award]] article.\n'
#  '*Rewrite [[Perkins Coie]] article.\n'
#  '*Rewrite articles on Rosewood properties.\n'
#  '*Expand [[New World China Land]] article.\n'
#  '*Rewrite articles on [[Resort]] and [[Hotel]].\n'
#  '*Expand [[Sowwah]] article.\n'
#  '*Create article on Sonia Cheng.\n'
#  '*Write Essay on under-served topic areas.\n'
#  '*Create article on US Azeris Network.\n'
#  '*Write Essay on wikipartisans.\n'
#  '*Expand article on [[Stefaan Engels]].\n'
#  '*Create article on Chuck Engle.\n'
#  '*Create article on Running Times Magazine.\n'
#  "*Improve article on [[Runner's World]] Magazine.\n"
#  '*Create article on Melissa Gillette.\n'
#  '*Create article on Doug Kurtis.\n'
#  '*Expand article on [[Association of Road Racing Statisticians]].\n'
#  '*Create article on indoor marathons.\n'
#  '*Turn [[Wikipedia:Notability (fiction)]] into a fitting proposal for a '
#  'guideline.\n'
#  '*Create article on Tim Siedell.\n'
#  '| width="50%" align="{{{align|left}}}" valign="{{{valign|top}}}" '
#  'style="border:0"|\n'
#  '*Create article on Canadian Running magazine.\n'
#  '*Create article on Sunbelt Ag Expo.\n'
#  '*Create article on James Chen President of [[Chinatrust Commercial Bank]].\n'
#  '*Create article on James Chen Founder of Adlens.\n'
#  '*Create article on Adlens.\n'
#  '*Create article on Alliance Magazine.\n'
#  '*Create article on Kim Klein.\n'
#  '*Create article on political support of Ron Paul.\n'
#  '*Create article on media coverage of Ron Paul.\n'
#  '*Create article on John Ramsey.\n'
#  '*Create article on Marshall Home.\n'
#  '*Create article on Wikimedia Germany.\n'
#  '*Create article on Wikimedia France.\n'
#  '*Create article on Christopher Dennis.\n'
#  '*Create article on Jon Davies.\n'
#  '*Create article on Raymond Cox (Stallion83)\n'
#  '*Create article on Cole Stryker.\n'
#  '*Create article on Doritos Locos Tacos.\n'
#  "*Create article on Moanin' (song).\n"
#  '*Create article on We Are Change.\n'
#  '*Create article on Luke Rudkowski.\n'
#  "*Create article on ''Intelligence and How to Get It''.\n"
#  "*Create article on ''Genes, People, and Languages''.\n"
#  '*Create article on The Amazing Atheist.\n'
#  '*Create article on Reginald T. Dorsey.\n'
#  '*Create article on Ice Princess saga.\n'
#  '*Recreate article on Flightless Bird, American Mouth\n'
#  "*Create article on ''Interventions: A Life in War and Peace''\n"
#  '*Create article on Nader Mousavizadeh\n'
#  '*Create article on Carrie the dancing dog\n'
#  "*Create article on ''Hot Chocolate Nutcracker''\n"
#  '*Create article on Virginia "Ginny" Busch\n'
#  '*Create article on Poornima Vijayashanker\n'
#  '*Create article on Tracy Chou\n'
#  '{{col-end}}\n'
#  '\n'
#  "== Articles I've created ==\n"
#  '\n'
#  '* [[Grassroots fundraising]]\n'
#  '* [[Kosovo independence precedent]]\n'
#  '* [[2008 Andean diplomatic crisis]]\n'
#  '* [[2008 unrest in Kosovo]]\n'
#  '* [[International Steering Group for Kosovo]]\n'
#  '* [[Kosovan local elections, 2008]]\n'
#  '* [[David E. Carter]]\n'
#  '* [[European Grouping for Territorial Cooperation]]\n'
#  '* [[2008 Georgia-Russia crisis\u200e]]\n'
#  '* [[2008 Djiboutian-Eritrean border conflict]]\n'
#  '* [[2008 Ukrainian political crisis]]\n'
#  '* [[2008 unrest in Bolivia]]\n'
#  '* [[Bankruptcy of Lehman Brothers]]\n'
#  '* [[Sosie Bacon]]\n'
#  '* [[North American integration]]\n'
#  '* [[Xue Hanqin]]\n'
#  '* [[Krista Branch]] {{icon|GA}}\n'
#  '* [[MovieWeb]] {{icon|DYK}}\n'
#  '* [[Wikimedia UK]] {{icon|DYK}}\n'
#  "* [[List of The Host characters|List of ''The Host'' characters]]\n"
#  "* [[List of Revolution episodes|List of ''Revolution'' episodes]]\n"
#  "* [[General Hospital's 50th anniversary]] {{icon|DYK}}\n"
#  '* [[The Fine Young Capitalists]] {{icon|DYK}}\n'
#  '\n'
#  "== Articles where I've made major contributions ==\n"
#  '\n'
#  '* [[Moneybomb]]\n'
#  '* [[North American Union]]\n'
#  '* [[Conspiracy theory]]\n'
#  '* [[NAFTA Superhighway]]\n'
#  '* [[Late-2000s recession]]\n'
#  '* [[Battle of the Kodori Valley]]\n'
#  '* [[Twelve Oaks Mall]]\n'
#  '* [[Abdul Rahman Hassan Azzam]]\n'
#  '* [[Collapse of the World Trade Center]]\n'
#  '* [[7 World Trade Center]]\n'
#  '* [[1948 Arab–Israeli War]]\n'
#  '* [[Zhijian James Chen]]\n'
#  "* [[Giordano's Pizzeria]]\n"
#  '* [[Emily Thorne]]\n'
#  '* [[Charlie Engle (infielder)]] {{icon|DYK}}\n'
#  '* [[Bai Yansong]] {{icon|DYK}}\n'
#  '* [[Anna Azari]] {{icon|DYK}}\n'
#  '* [[List of Wikipedia controversies]] [[File:Dollar symbol '
#  'gold.svg|10px|Cha-ching!]]\n'
#  '* [[Wikipediocracy]]\n'
#  "* ''[[RWBY]]'' {{icon|DYK}}\n"
#  "* [[List of RWBY episodes|List of ''RWBY'' episodes]]\n"
#  '* [[Pricasso]]\n'
#  '* [[Stanton Foundation]] [[File:Dollar symbol gold.svg|10px|Cha-ching!]]\n'
#  '\n'
#  "== Essays I've written ==\n"
#  '* [[Wikipedia:Disruptive sanctions]]\n'
#  '\n'
#  "== Good article nominations I've reviewed ==\n"
#  '*[[Talk:Otis Redding/GA3|Otis Redding]] (second opinion)\n'
#  '*[[Talk:Revelation (Third Day album)/GA1|Revelation (Third Day album)]]\n'
#  '*[[Talk:History of Evansville, Indiana/GA1|History of Evansville, Indiana]]\n'
#  '*[[Talk:Anne Rice/GA1|Anne Rice]]\n'
#  '*[[Talk:Brooks & Dunn/GA1|Brooks & Dunn]]\n'
#  '*[[Talk:James Randi/GA1|James Randi]]\n'
#  '*[[Talk:Knights of Columbus/GA1|Knights of Columbus]]\n'
#  '*[[Talk:Paul Ryan/GA1|Paul Ryan]]\n'
#  '\n'
#  '== Tools ==\n'
#  '*[https://tools.wmflabs.org/xtools/topedits/index.php? Top namespace edits]\n'
#  '*[http://toolserver.org/~mzmcbride/stalker/ Wikistalk]\n'
#  '*[http://toolserver.org/~snottywong/editorinteract.html Editor interaction '
#  'analyzer]\n'
#  '*[http://toolserver.org/~tparis/autoedits/ Automated edit counter]\n'
#  '*[http://toolserver.org/~snottywong/adminscore.html Admin score]\n'
#  '\n'
#  '== Userboxes ==\n'
#  '{{collapse top|Politics}}\n'
#  '{| class="wikitable"\n'
#  '|-\n'
#  '| {{Template:user history2}}\n'
#  '| {{User:Scepia/geopolitics}}\n'
#  '| {{User:J.P.Lon/Userboxes/Interest-Economics}}\n'
#  '|-\n'
#  '| {{User:Quoth the Raven/Userboxes/Political Science}}\n'
#  '| {{User:Gordalmighty/Userbox/Ron Paul}}\n'
#  '|  {{User:Dailynetworks/ubx/IndependentVoter}}\n'
#  '|-\n'
#  '| {{User:Libertyville/ProLife}} \n'
#  '| {{User:StuffOfInterest/Userboxes/User no death penalty}}\t\n'
#  '| {{User:WebHamster/fucking}}\n'
#  '|-\n'
#  '| {{User:Scartol/Userboxes/nonviolence}}\n'
#  '| {{User:Tedius Zanarukando/Userboxes/User cvg proponent}}\n'
#  "| {{User:The Raven's Apprentice/Userboxes/User Against Censorship}}\n"
#  '|-\n'
#  '| {{User:Tedius Zanarukando/Userboxes/User region free}}\n'
#  '| {{User:SpikeToronto/userboxes/No Political Correctness}}\n'
#  '| {{User Citizen Media}} \n'
#  '|-\n'
#  '| {{User Sustainable Living}}\n'
#  '| {{User Renewable Energy}}\n'
#  '| {{User:Ash/Userboxes/Freecycle}} \n'
#  '|-\n'
#  '| {{User:Ash/Userboxes/Recycle}}\n'
#  '| {{User:Ash/Userboxes/Regiving}}\n'
#  '| {{User:Disavian/Userboxes/Public Transit}}\n'
#  '|-\n'
#  '| {{User:Wintran/Userboxes/Immigration}}\n'
#  '| {{User:SpikeToronto/userboxes/Same sex marriage}}\n'
#  '| {{User:Bluedenim/Drugs}} \n'
#  '|-\n'
#  '| {{User:Triadian/Userboxes/UN Reform}}\n'
#  '| {{User:Djr xi/User bad EU}}\n'
#  '| {{User:UBX/User Swiss direct democracy}} \n'
#  '|- \t\n'
#  '| {{User:DieWeisseRose/Userboxes/OneState}}\n'
#  '| {{User:Triadian/Userboxes/Stable Iraq}}\n'
#  '| {{User:MQDuck/userboxes/Right_To_Resist}}\n'
#  '|-\n'
#  '| \n'
#  "| {{User:Sappho'd/Userboxes/Conspiracybutnoreptoids}}\n"
#  '|  \n'
#  '|}\n'
#  '{{clear}}\n'
#  '{{collapse bottom}}\n'
#  '\n'
#  '{{collapse top|Music}}\n'
#  '{| class="wikitable"\n'
#  '| {{User:Scepia/all music}}\n'
#  '| {{User:Eternal dragon/Userboxes/QueenBohemianRhapsody}}\n'
#  '| {{User:DannyQuack/Userboxes/Switchfoot}} \n'
#  '|-\n'
#  '| {{User:UBX/ColdPlay}}\n'
#  '| {{User:UBX/Evanescence}}\n'
#  '| {{User:UBX/REM}} \n'
#  '|-\n'
#  '| {{User:UBX/User Weird Al 2}}\n'
#  "| {{User:UBX/don't wanna}}\n"
#  '| {{Template: User LP}} \n'
#  '|-\n'
#  '| {{User Iron Man}}\n'
#  '| {{User Enter Sandman}}\n'
#  '| {{User Closer (Nine Inch Nails song)}} \n'
#  '|-\n'
#  '| {{User:UBX/NC}}\n'
#  '| {{User:UBX/Beach Boys}}\n'
#  '| {{User:UBX/Beatles}} \n'
#  '|-\n'
#  '| {{Template:User notslim}}\n'
#  '| {{User:UBX/Tom Waits}}\n'
#  '| {{User:Pokerdance/Lady Gaga fan}}\n'
#  '|-\n'
#  '| {{User:Tuzapicabit/Userboxes/Dancing Queen}}\n'
#  '| {{User:Scepia/CVG music}}\n'
#  '| {{User:The Arbiter/UBX/Love Story}}\n'
#  '\n'
#  '|}\n'
#  '{{clear}}\n'
#  '{{collapse bottom}}\n'
#  '\n'
#  '{{collapse top|Science Fiction}}\n'
#  '{| class="wikitable"\n'
#  '|-\n'
#  '| {{User:Fultron89/Userboxes/fultronmatrix}}\n'
#  '| {{User:UBX/swpm}}\n'
#  '| {{User:UBX/Rebel Alliance 2}}\n'
#  '|-\n'
#  '| {{User:Merond e/StarWars-truelight}}\n'
#  '| {{User:UBX/Theforce}}\n'
#  '| {{User:UBX/Chewbacca}}\n'
#  '|}\n'
#  '{{clear}}\n'
#  '{{collapse bottom}}\n'
#  '\n'
#  '{{collapse top|Literature}}\n'
#  '{| class="wikitable"\n'
#  '|-\n'
#  '| {{User:Chamal N/Userboxes/The hobbit}}\n'
#  '| {{User:Royalguard11/userboxes/Tolkien}}\n'
#  '| {{User:UBX/User LOTR}}\n'
#  '|-\n'
#  '| {{User:Scepia/Watchmen}}\n'
#  '| {{User:UBX/Cthulhu}}\n'
#  '| {{User:Mkdw/HGG}}\n'
#  '|-\n'
#  '| {{User:Jimmy da tuna/Userboxes/orgy-porgy}}\n'
#  '| {{User:Twooars/Userboxes/Rules and agreement}}\n'
#  '| {{User:Scepia/Orwell}}\n'
#  '|}\n'
#  '{{clear}}\n'
#  '{{collapse bottom}}\n'
#  '\n'
#  '{{collapse top|Science and Philosophy}}\n'
#  '{| class="wikitable"\n'
#  '|-\n'
#  '| {{User:UBX/Medieval spherical earth}}\n'
#  '| {{User:P.B. Pilhet/UBX/Evolution}}\n'
#  '| {{User:UBX/Religion}}\n'
#  '|-\n'
#  '| {{User:WebHamster/belief}}\n'
#  '| {{User:Wintran/Userboxes/Belief respect}}\n'
#  '| {{User:UBX/Meher Baba3}}\n'
#  '|-\n'
#  '| \n'
#  "| {{User:The Devil's Advocate/trueskeptic}}\n"
#  '| \n'
#  '|}\n'
#  '{{clear}}\n'
#  '{{collapse bottom}}\n'
#  '{{collapse top|Video Games}}\n'
#  '{| class="wikitable"\n'
#  '|-\n'
#  '| {{User:Oxguy3/myboxes/favm-Yoshi}}\n'
#  '| {{User:Llama man/Userboxes/Zelda}}\n'
#  "| {{User:UBX/Assassin's Creed}}\n"
#  '|}\n'
#  '{{clear}}\n'
#  '{{collapse bottom}}\n'
#  '{{collapse top|Animé}}\n'
#  '{| class="wikitable"\n'
#  '|-\n'
#  '| {{Wikipedia:WikiProject Anime and manga/Userbox/User anime-4}}\n'
#  '| {{Wikipedia:WikiProject Anime and manga/Userbox/User sub}}\n'
#  '| {{User:ISD/Userboxes/Gurren Lagann 2}}\n'
#  '|-\n'
#  '| {{User:Alexjohnc3/Userboxes/user Haruhiism}}\n'
#  '| {{User:Averross/Puchu}}\n'
#  '| {{Wikipedia:WikiProject Anime and manga/Userbox/User Samurai Champloo 2}}\n'
#  '|-\n'
#  '| {{Wikipedia:WikiProject Anime and manga/Userbox/User Ghostintheshell2}}\n'
#  '| {{Wikipedia:WikiProject Anime and manga/Userbox/User GunslingerGirl}}\n'
#  '| {{Wikipedia:WikiProject Anime and manga/Userbox/User Fruits Basket}}\n'
#  '|-\n'
#  '| {{Wikipedia:WikiProject Anime and manga/Userbox/User Oreimo watch}}\n'
#  '| {{Wikipedia:WikiProject Anime and manga/Userbox/User One Piece}}\n'
#  '| {{Wikipedia:WikiProject Anime and manga/Userbox/User Full Metal Panic}}\n'
#  '|-\n'
#  '| {{User:Dwscomet/My userbox creations/AttackonTitan}}\n'
#  '| {{Wikipedia:WikiProject Anime and manga/Userbox/User Negima}}\n'
#  "| {{User:The Devil's Advocate/RWBY}}\n"
#  '|}\n'
#  '{{collapse bottom}}\n')

# %%
source_text_clean = source.text.split(u'{{Userboxtop')[1].split(u"{{Userboxbottom}}")[0]

# %%
pprint(source_text_clean)
# Out:
# ("|The Devil's Advocate|bordercolor=#000000}}\n"
#  '{{User:Jer10 95/privatename}}\n'
#  '{{user:hmwith/ubx/male}}\n'
#  '{{User:UserBox/User Earthling}}\n'
#  '{{user en}}\n'
#  '{{User:Ashley Y/Userbox/Agnostic}}\n'
#  '{{User:UBX/girlfriendwish}}\n'
#  '{{User:JLogan/LesSym}}\n'
#  '{{User:UBX/Coke Pepsi}}\n'
#  '{{Template:user ancestry multi}}\n'
#  '{{Template:User Immortal}}\n'
#  '{{User Wikimedia Commons}}\n'
#  '{{userbox\n'
#  '|id=[[File:Box-cutter.jpg|50px]]\n'
#  "|info=This user reads '''[[Wikipediocracy]]'''\n"
#  '}}\n'
#  '{{User:Boing! said Zebedee/Userboxes/noadmin}}\n'
#  '{{User:UBX/Twinkle4}}\n'
#  '{{User wikipedia/WikiDragon2}}\n'
#  '{{User edit}}\n'
#  '{{User recursively neutral}}\n'
#  '{{User:SpeakFree/no barnstar}}\n'
#  '{{Template:User WikiPeace}}\n'
#  '{{User:Running/wikipe-tan}}\n'
#  '{{User:JohnRussell/wikipedianumedits|19,000}}\n'
#  '{{User:Timeastor/personality versatile}}\n'
#  '{{User:Menasim/Userboxes/User quote|"All men can be criminals, if tempted; '
#  'all men can be heroes, if inspired."\n'
#  '|G. K. Chesterton}}\n'
#  '{{User:Scepia/beauty}}\n'
#  '{{User:Scepia/HDTV}}\n'
#  '{{User:Feureau/UserBox/ubx-5}}\n')

# %%
import re
userbox = re.findall('(User:.*)}}', source_text_clean, re.IGNORECASE)

# %%
for template in re.findall('(Template:.*)}}', source_text_clean, re.IGNORECASE):
    userbox.append(template)

# %%
userbox
# Out:
# ['User:Jer10 95/privatename',
#  'user:hmwith/ubx/male',
#  'User:UserBox/User Earthling',
#  'User:Ashley Y/Userbox/Agnostic',
#  'User:UBX/girlfriendwish',
#  'User:JLogan/LesSym',
#  'User:UBX/Coke Pepsi',
#  'User:Boing! said Zebedee/Userboxes/noadmin',
#  'User:UBX/Twinkle4',
#  'User:SpeakFree/no barnstar',
#  'User:Running/wikipe-tan',
#  'User:JohnRussell/wikipedianumedits|19,000',
#  'User:Timeastor/personality versatile',
#  'User:Scepia/beauty',
#  'User:Scepia/HDTV',
#  'User:Feureau/UserBox/ubx-5',
#  'Template:user ancestry multi',
#  'Template:User Immortal',
#  'Template:User WikiPeace']

# %%
userbox_url = []

for ubx in userbox:
    ubx_url = "https://en.wikipedia.org/wiki/" + ubx
    userbox_url.append(ubx_url)
    
userbox_url
# Out:
# ['https://en.wikipedia.org/wiki/User:Jer10 95/privatename',
#  'https://en.wikipedia.org/wiki/user:hmwith/ubx/male',
#  'https://en.wikipedia.org/wiki/User:UserBox/User Earthling',
#  'https://en.wikipedia.org/wiki/User:Ashley Y/Userbox/Agnostic',
#  'https://en.wikipedia.org/wiki/User:UBX/girlfriendwish',
#  'https://en.wikipedia.org/wiki/User:JLogan/LesSym',
#  'https://en.wikipedia.org/wiki/User:UBX/Coke Pepsi',
#  'https://en.wikipedia.org/wiki/User:Boing! said Zebedee/Userboxes/noadmin',
#  'https://en.wikipedia.org/wiki/User:UBX/Twinkle4',
#  'https://en.wikipedia.org/wiki/User:SpeakFree/no barnstar',
#  'https://en.wikipedia.org/wiki/User:Running/wikipe-tan',
#  'https://en.wikipedia.org/wiki/User:JohnRussell/wikipedianumedits|19,000',
#  'https://en.wikipedia.org/wiki/User:Timeastor/personality versatile',
#  'https://en.wikipedia.org/wiki/User:Scepia/beauty',
#  'https://en.wikipedia.org/wiki/User:Scepia/HDTV',
#  'https://en.wikipedia.org/wiki/User:Feureau/UserBox/ubx-5',
#  'https://en.wikipedia.org/wiki/Template:user ancestry multi',
#  'https://en.wikipedia.org/wiki/Template:User Immortal',
#  'https://en.wikipedia.org/wiki/Template:User WikiPeace']
